# %% [markdown]
# # Bag-of-Words 👜 Model
# One popular text representation technique is Bag-of-Words (BoW) model. In the bag of words model text or the documents are represented by modeling a bag (unordered collection) of words. This bag of words does not count the positioning, grammar or structure of the words in the text. It just count the frequencies of words in the target text and put that words in to a bag. The frequencies of words appearing in a text (sentence or document) is the feature that is used on bag-of-words model.<br>
#
# Consider following set (D) of documents
#
# *document 1*: Bob is clever than the others
# *document 2*: John loves to explore the stars at night
# *document 3*: The sun is shining in the sky
# *document 4*: The night sky is full of stars
#
# After doing mentioned preprocessing steps, our four documents will be,
# *document 1*: bob is clever than the others
# *document 2*: john loves to explore the stars at night
# *document 3*: the sun is shining in the sky
# *document 4*: the night sky is full of stars
#
#
# Now, we can create our bag 👜 of words as follows.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tf-Idf for text Representation
#
# Tf-Idf (Term frequency — Inverse document frequency) is a bag-of-word model which is very powerful in capturing the most important words in your text. The concept behind the Tf-Idf can be understood by the term frequency (Tf) and inverse document frequency (Idf). The collective representation generated from Tf and Idf representations is called Tf-Idf and it is a powerful way of representing text data. <br>
#
# ### Term Frequency (TF)
# Term frequency is a function of term(word) t and document d.
#
# $$ TF(t,d) = {\text{number of occurances of the term t in document d} \over \text{number of terms present in document d}} $$
#
# The document columns in the following table represent the Tf vector for each document.
#
# ![image.png](attachment:image.png)
#
# ### Inverse Document Frequency (Idf)
# Inverse document frequency (Idf) is a measurement of uniqueness of a term to a document with respect to a corpus of documents
#
# $$ Idf(t) = \log[{\text{number of documents} \over \text{number of documents containing term t}}] $$
#
# ![image-2.png](attachment:image-2.png)
#
# Then TF_IDF is:
#
# $$ Tf-Idf(t,d,D) = Tf(t,d) * Idf(t,D) $$
#
# |![image-3.png](attachment:image-3.png)|
# |:--:|
# |*Tf-Idf representation calculated using Tf and Idf.*|

# %% [markdown]
# ## Shortcomings of Tf-Idf
# Even though, Tf-Idf is so much powerful technique to represent text data it is still a BoW model. Therefore Tf-Idf does not count the positioning of words in the document. This may lead Tf-Idf to give wrong interpretation on your text data.<br>
#
# For example,
# document 1 : Bob is clever than Alice<br>
# document 2 : Alice is clever than Bob<br>
#
# have same set ({ ‘bob’’, ‘is’, ‘’clever’’, ‘’than’’, ‘’alice’’ }) of words with same word frequencies, but they give different meanings. But, Tf-Idf as a BoW text representation model will give you same representations for both documents. One other major shortcoming that can be seen in Tf-Idf model is it consumes a lot of memory and processing power.
