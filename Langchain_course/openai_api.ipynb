# %%
# !pip install openai
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/225.1 kB ? eta -:--:--
#    ---------------------------------------- 225.1/225.1 kB 6.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/75.9 kB ? eta -:--:--
#    ---------------------------------------- 75.9/75.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    ---------------------------------------- 76.9/76.9 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import OpenAI
import os

# %%
llm = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

# %%
llm("What's special about 26th January 2024?")
# Out:
# c:\Users\ketan\Anaconda3\envs\langchain\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# d:\KETAN\ds_notes\Langchain_course\openai_api.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/KETAN/ds_notes/Langchain_course/openai_api.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> llm("What's special about 26th January 2024?")
#
# File c:\Users\ketan\Anaconda3\envs\langchain\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# ...
