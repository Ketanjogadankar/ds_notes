# %% [markdown]
# # Neural Network
#
# As shown in below network, Deep neural network has many layers consisting of single input and output layer with multiple hidden layers.
#
# ![image.png](attachment:image.png)
#
# Node in neural network.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Forward Propagation

# %% [markdown]
# In forward propagation, NN calculates activation function using
